# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
import pandas as pd

# Assuming `y` is your numpy array with audio samples and `sr` is the sampling rate
# For example:
# y = np.random.randn(22050*10)  # An example numpy array of random noise
datapath = '../pages/app_data/current_data.csv'
data = pd.read_csv(datapath)

y = np.array(data.y)
sr = 22050  # Example sampling rate

# Compute the mel spectrogram
S = librosa.feature.melspectrogram(y=y, sr=sr)

# Convert to dB (log scale)
S_dB = librosa.power_to_db(S, ref=np.max)

# Plotting
plt.figure(figsize=(10, 4))
librosa.display.specshow(S_dB, sr=sr, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency spectrogram')
plt.tight_layout()
plt.show()

# %%
x = np.linspace(0, 9, 1000)
y = np.sin(x)
sr = 1000  # Example sampling rate

# Compute the mel spectrogram
S = librosa.feature.melspectrogram(y=y, sr=sr)

# Convert to dB (log scale)
S_dB = librosa.power_to_db(S)

# Plotting
plt.figure(figsize=(10, 4))
librosa.display.specshow(S_dB, sr=sr, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Mel-frequency spectrogram')
plt.tight_layout()
plt.show()
